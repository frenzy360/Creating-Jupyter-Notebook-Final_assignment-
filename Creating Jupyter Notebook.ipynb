# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Sean Mitchell</b>
# <br> Data Scientist

# %% [markdown]
# <i>I am interested in Data Science because I love working with data! Utilizing visualization tools and solve complex problems with data is something I’m very passionate about. The ability to solve problems and tell stories with data is very intriguing to me.</i>

# %% [markdown]
# ### Stores string in variable and prints contetns of the sting togeter

# %%
First_String = "I love"
Second_String = " Data Science"
print(First_String + Second_String)
# Out:
# I love Data Science

# %% [markdown]
# Data Science has many different things you may have to learn if you will like to become a Data Scientists
# 1. Progroamming
#  * Python
#  * SQL
#
#
# 2. Math
#   * Statistics
#
#
# Jupyter Notebook is a great tool to use for Python. What makes Jupyter special is that the output (grapgs/data tables) can be displayed all in the same place. For example, look at the use of a markdown cell to display a table
#
# Bellow displays 4 math symbols and their mathmatical name
# -------------------------------
# | Math computation  | Symbol |
# | --- | --- |
# | Addition          |   +    |
# |                   |        |
# | Subtraction       |   -    |
# |                   |        |
# | Multiplication    |   x    |
# |                   |        |
# | Division          |   /    |
#
#
# In this markdown cell I demonstrated features within a markdown cell
# Horizontal rule, bulleted list, numbered list, and table.
